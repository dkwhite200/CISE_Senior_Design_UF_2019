# %%
# MNSIT TRAINING SET

import numpy as np
import tensorflow as tf
from scipy import misc

n_inputs = 28*28
n_hidden1 = 300
n_hidden2 = 100
n_outputs = 10

X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
y = tf.placeholder(tf.int64, shape=(None), name="y")

def neuron_layer(X, n_neurons, name, activation=None):
    with tf.name_scope(name):
        n_inputs = int(X.get_shape()[1])
        stddev = 2 / np.sqrt(n_inputs)
        init = tf.truncated_normal((n_inputs, n_neurons), stddev=stddev)
        W = tf.Variable(init, name="weights")
        b = tf.Variable(tf.zeros([n_neurons]), name="biases")
        z = tf.matmul(X,W) + b
        if activation=="relu":
            return tf.nn.relu(z)
        else:
            return z

with tf.name_scope("dnn"):
    hidden1 = neuron_layer(X, n_hidden1, "hidden1", activation="relu")
    hidden2 = neuron_layer(hidden1, n_hidden2, "hidden2", activation="relu")
    logits = neuron_layer(hidden2, n_outputs, "outputs")

    
with tf.name_scope("loss"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy, name="loss")

learning_rate = 0.01

with tf.name_scope("train"):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)
    
with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))
    
init = tf.global_variables_initializer()
saver = tf.train.Saver()

from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/")

n_epochs = 400
batch_size = 50

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        for iter in range(mnist.train.num_examples // batch_size):
            X_batch, y_batch = mnist.train.next_batch(batch_size)
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_train = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
        acc_test = accuracy.eval(feed_dict={X: mnist.test.images, y: mnist.test.labels})
        print(epoch, "Train accuracy:", acc_train, "Test accuracy", acc_test)
    save_path = saver.save(sess, "./my_model_final.ckpt")
# Out:
# WARNING:tensorflow:From <ipython-input-11-a15c950b9f1c>:50: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /home/dkwhite200/.local/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /home/dkwhite200/.local/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use urllib or similar directly.
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# WARNING:tensorflow:From /home/dkwhite200/.local/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# WARNING:tensorflow:From /home/dkwhite200/.local/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /home/dkwhite200/.local/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# 0 Train accuracy: 0.92 Test accuracy 0.9149
# 1 Train accuracy: 0.88 Test accuracy 0.9302
# 2 Train accuracy: 0.96 Test accuracy 0.9388
# 3 Train accuracy: 0.9 Test accuracy 0.9443
# 4 Train accuracy: 0.92 Test accuracy 0.9497
# 5 Train accuracy: 0.98 Test accuracy 0.9529
# 6 Train accuracy: 0.9 Test accuracy 0.9572
# 7 Train accuracy: 0.98 Test accuracy 0.9601
# 8 Train accuracy: 0.96 Test accuracy 0.9619
# 9 Train accuracy: 0.98 Test accuracy 0.9646
# 10 Train accuracy: 1.0 Test accuracy 0.9653
# 11 Train accuracy: 0.96 Test accuracy 0.9671
# 12 Train accuracy: 0.98 Test accuracy 0.9691
# 13 Train accuracy: 0.96 Test accuracy 0.9694
# 14 Train accuracy: 0.94 Test accuracy 0.9686
# 15 Train accuracy: 0.98 Test accuracy 0.9701
# 16 Train accuracy: 0.96 Test accuracy 0.9708
# 17 Train accuracy: 0.98 Test accuracy 0.9715
# 18 Train accuracy: 1.0 Test accuracy 0.9727
# 19 Train accuracy: 0.98 Test accuracy 0.9728
# 20 Train accuracy: 1.0 Test accuracy 0.973
# 21 Train accuracy: 1.0 Test accuracy 0.9719
# 22 Train accuracy: 0.98 Test accuracy 0.9743
# 23 Train accuracy: 1.0 Test accuracy 0.9737
# 24 Train accuracy: 1.0 Test accuracy 0.9739
# 25 Train accuracy: 1.0 Test accuracy 0.9747
# 26 Train accuracy: 0.98 Test accuracy 0.9749
# 27 Train accuracy: 1.0 Test accuracy 0.9756
# 28 Train accuracy: 1.0 Test accuracy 0.976
# 29 Train accuracy: 0.98 Test accuracy 0.9747
# 30 Train accuracy: 1.0 Test accuracy 0.9762
# 31 Train accuracy: 1.0 Test accuracy 0.977
# 32 Train accuracy: 0.98 Test accuracy 0.9773
# 33 Train accuracy: 1.0 Test accuracy 0.9769
# 34 Train accuracy: 1.0 Test accuracy 0.9767
# 35 Train accuracy: 0.98 Test accuracy 0.977
# 36 Train accuracy: 0.98 Test accuracy 0.9776
# 37 Train accuracy: 0.98 Test accuracy 0.9772
# 38 Train accuracy: 1.0 Test accuracy 0.9774
# 39 Train accuracy: 1.0 Test accuracy 0.9772
# 40 Train accuracy: 1.0 Test accuracy 0.978
# 41 Train accuracy: 1.0 Test accuracy 0.978
# 42 Train accuracy: 1.0 Test accuracy 0.9774
# 43 Train accuracy: 1.0 Test accuracy 0.9777
# 44 Train accuracy: 1.0 Test accuracy 0.9786
# 45 Train accuracy: 1.0 Test accuracy 0.9779
# 46 Train accuracy: 1.0 Test accuracy 0.9776
# 47 Train accuracy: 1.0 Test accuracy 0.9779
# 48 Train accuracy: 1.0 Test accuracy 0.9777
# 49 Train accuracy: 1.0 Test accuracy 0.9779
# 50 Train accuracy: 1.0 Test accuracy 0.9779
# 51 Train accuracy: 1.0 Test accuracy 0.9785
# 52 Train accuracy: 1.0 Test accuracy 0.9786
# 53 Train accuracy: 1.0 Test accuracy 0.9784
# 54 Train accuracy: 1.0 Test accuracy 0.9788
# 55 Train accuracy: 1.0 Test accuracy 0.9783
# 56 Train accuracy: 1.0 Test accuracy 0.9788
# 57 Train accuracy: 1.0 Test accuracy 0.9776
# 58 Train accuracy: 1.0 Test accuracy 0.9788
# 59 Train accuracy: 1.0 Test accuracy 0.9787
# 60 Train accuracy: 1.0 Test accuracy 0.9789
# 61 Train accuracy: 1.0 Test accuracy 0.9783
# 62 Train accuracy: 1.0 Test accuracy 0.9794
# 63 Train accuracy: 1.0 Test accuracy 0.9788
# 64 Train accuracy: 1.0 Test accuracy 0.9792
# 65 Train accuracy: 1.0 Test accuracy 0.9791
# 66 Train accuracy: 1.0 Test accuracy 0.9788
# 67 Train accuracy: 1.0 Test accuracy 0.9795
# 68 Train accuracy: 1.0 Test accuracy 0.9791
# 69 Train accuracy: 1.0 Test accuracy 0.9794
# 70 Train accuracy: 1.0 Test accuracy 0.9792
# 71 Train accuracy: 1.0 Test accuracy 0.9793
# 72 Train accuracy: 1.0 Test accuracy 0.9785
# 73 Train accuracy: 1.0 Test accuracy 0.9793
# 74 Train accuracy: 1.0 Test accuracy 0.979
# 75 Train accuracy: 1.0 Test accuracy 0.9794
# 76 Train accuracy: 1.0 Test accuracy 0.9794
# 77 Train accuracy: 1.0 Test accuracy 0.9792
# 78 Train accuracy: 1.0 Test accuracy 0.9798
# 79 Train accuracy: 1.0 Test accuracy 0.979
# 80 Train accuracy: 1.0 Test accuracy 0.9793
# 81 Train accuracy: 1.0 Test accuracy 0.9796
# 82 Train accuracy: 1.0 Test accuracy 0.9797
# 83 Train accuracy: 1.0 Test accuracy 0.9794
# 84 Train accuracy: 1.0 Test accuracy 0.9795
# 85 Train accuracy: 1.0 Test accuracy 0.9798
# 86 Train accuracy: 1.0 Test accuracy 0.9795
# 87 Train accuracy: 1.0 Test accuracy 0.979
# 88 Train accuracy: 1.0 Test accuracy 0.9796
# 89 Train accuracy: 1.0 Test accuracy 0.9795
# 90 Train accuracy: 1.0 Test accuracy 0.9799
# 91 Train accuracy: 1.0 Test accuracy 0.9801
# 92 Train accuracy: 1.0 Test accuracy 0.9797
# 93 Train accuracy: 1.0 Test accuracy 0.9798
# 94 Train accuracy: 1.0 Test accuracy 0.9797
# 95 Train accuracy: 1.0 Test accuracy 0.9802
# 96 Train accuracy: 1.0 Test accuracy 0.9795
# 97 Train accuracy: 1.0 Test accuracy 0.9796
# 98 Train accuracy: 1.0 Test accuracy 0.9798
# 99 Train accuracy: 1.0 Test accuracy 0.9797
# 100 Train accuracy: 1.0 Test accuracy 0.9798
# 101 Train accuracy: 1.0 Test accuracy 0.9799
# 102 Train accuracy: 1.0 Test accuracy 0.9791
# 103 Train accuracy: 1.0 Test accuracy 0.9795
# 104 Train accuracy: 1.0 Test accuracy 0.9801
# 105 Train accuracy: 1.0 Test accuracy 0.9799
# 106 Train accuracy: 1.0 Test accuracy 0.9794
# 107 Train accuracy: 1.0 Test accuracy 0.9801
# 108 Train accuracy: 1.0 Test accuracy 0.9797
# 109 Train accuracy: 1.0 Test accuracy 0.9798
# 110 Train accuracy: 1.0 Test accuracy 0.9799
# 111 Train accuracy: 1.0 Test accuracy 0.9798
# 112 Train accuracy: 1.0 Test accuracy 0.9796
# 113 Train accuracy: 1.0 Test accuracy 0.9793
# 114 Train accuracy: 1.0 Test accuracy 0.9801
# 115 Train accuracy: 1.0 Test accuracy 0.98
# 116 Train accuracy: 1.0 Test accuracy 0.9799
# 117 Train accuracy: 1.0 Test accuracy 0.9797
# 118 Train accuracy: 1.0 Test accuracy 0.9798
# 119 Train accuracy: 1.0 Test accuracy 0.9798
# 120 Train accuracy: 1.0 Test accuracy 0.98
# 121 Train accuracy: 1.0 Test accuracy 0.98
# 122 Train accuracy: 1.0 Test accuracy 0.9802
# 123 Train accuracy: 1.0 Test accuracy 0.98
# 124 Train accuracy: 1.0 Test accuracy 0.9798
# 125 Train accuracy: 1.0 Test accuracy 0.9797
# 126 Train accuracy: 1.0 Test accuracy 0.9801
# 127 Train accuracy: 1.0 Test accuracy 0.9798
# 128 Train accuracy: 1.0 Test accuracy 0.98
# 129 Train accuracy: 1.0 Test accuracy 0.9799
# 130 Train accuracy: 1.0 Test accuracy 0.9799
# 131 Train accuracy: 1.0 Test accuracy 0.98
# 132 Train accuracy: 1.0 Test accuracy 0.9799
# 133 Train accuracy: 1.0 Test accuracy 0.9801
# 134 Train accuracy: 1.0 Test accuracy 0.9798
# 135 Train accuracy: 1.0 Test accuracy 0.9803
# 136 Train accuracy: 1.0 Test accuracy 0.9798
# 137 Train accuracy: 1.0 Test accuracy 0.9799
# 138 Train accuracy: 1.0 Test accuracy 0.9798
# 139 Train accuracy: 1.0 Test accuracy 0.9797
# 140 Train accuracy: 1.0 Test accuracy 0.9798
# 141 Train accuracy: 1.0 Test accuracy 0.98
# 142 Train accuracy: 1.0 Test accuracy 0.9796
# 143 Train accuracy: 1.0 Test accuracy 0.9802
# 144 Train accuracy: 1.0 Test accuracy 0.9801
# 145 Train accuracy: 1.0 Test accuracy 0.9802
# 146 Train accuracy: 1.0 Test accuracy 0.9798
# 147 Train accuracy: 1.0 Test accuracy 0.9799
# 148 Train accuracy: 1.0 Test accuracy 0.98
# 149 Train accuracy: 1.0 Test accuracy 0.9804
# 150 Train accuracy: 1.0 Test accuracy 0.9802
# 151 Train accuracy: 1.0 Test accuracy 0.9799
# 152 Train accuracy: 1.0 Test accuracy 0.98
# 153 Train accuracy: 1.0 Test accuracy 0.98
# 154 Train accuracy: 1.0 Test accuracy 0.9799
# 155 Train accuracy: 1.0 Test accuracy 0.9803
# 156 Train accuracy: 1.0 Test accuracy 0.98
# 157 Train accuracy: 1.0 Test accuracy 0.9801
# 158 Train accuracy: 1.0 Test accuracy 0.9798
# 159 Train accuracy: 1.0 Test accuracy 0.98
# 160 Train accuracy: 1.0 Test accuracy 0.9803
# 161 Train accuracy: 1.0 Test accuracy 0.9799
# 162 Train accuracy: 1.0 Test accuracy 0.9799
# 163 Train accuracy: 1.0 Test accuracy 0.98
# 164 Train accuracy: 1.0 Test accuracy 0.9799
# 165 Train accuracy: 1.0 Test accuracy 0.9802
# 166 Train accuracy: 1.0 Test accuracy 0.9803
# 167 Train accuracy: 1.0 Test accuracy 0.9799
# 168 Train accuracy: 1.0 Test accuracy 0.98
# 169 Train accuracy: 1.0 Test accuracy 0.98
# 170 Train accuracy: 1.0 Test accuracy 0.9799
# 171 Train accuracy: 1.0 Test accuracy 0.9801
# 172 Train accuracy: 1.0 Test accuracy 0.9802
# 173 Train accuracy: 1.0 Test accuracy 0.9803
# 174 Train accuracy: 1.0 Test accuracy 0.9801
# 175 Train accuracy: 1.0 Test accuracy 0.9799
# 176 Train accuracy: 1.0 Test accuracy 0.9798
# 177 Train accuracy: 1.0 Test accuracy 0.9801
# 178 Train accuracy: 1.0 Test accuracy 0.9801
# 179 Train accuracy: 1.0 Test accuracy 0.9799
# 180 Train accuracy: 1.0 Test accuracy 0.9803
# 181 Train accuracy: 1.0 Test accuracy 0.98
# 182 Train accuracy: 1.0 Test accuracy 0.9802
# 183 Train accuracy: 1.0 Test accuracy 0.9801
# 184 Train accuracy: 1.0 Test accuracy 0.9798
# 185 Train accuracy: 1.0 Test accuracy 0.9801
# 186 Train accuracy: 1.0 Test accuracy 0.9801
# 187 Train accuracy: 1.0 Test accuracy 0.9798
# 188 Train accuracy: 1.0 Test accuracy 0.9799
# 189 Train accuracy: 1.0 Test accuracy 0.9799
# 190 Train accuracy: 1.0 Test accuracy 0.9801
# 191 Train accuracy: 1.0 Test accuracy 0.9803
# 192 Train accuracy: 1.0 Test accuracy 0.98
# 193 Train accuracy: 1.0 Test accuracy 0.9799
# 194 Train accuracy: 1.0 Test accuracy 0.9801
# 195 Train accuracy: 1.0 Test accuracy 0.9801
# 196 Train accuracy: 1.0 Test accuracy 0.9801
# 197 Train accuracy: 1.0 Test accuracy 0.98
# 198 Train accuracy: 1.0 Test accuracy 0.9801
# 199 Train accuracy: 1.0 Test accuracy 0.9802
# 200 Train accuracy: 1.0 Test accuracy 0.9803
# 201 Train accuracy: 1.0 Test accuracy 0.98
# 202 Train accuracy: 1.0 Test accuracy 0.9804
# 203 Train accuracy: 1.0 Test accuracy 0.98
# 204 Train accuracy: 1.0 Test accuracy 0.98
# 205 Train accuracy: 1.0 Test accuracy 0.9801
# 206 Train accuracy: 1.0 Test accuracy 0.9802
# 207 Train accuracy: 1.0 Test accuracy 0.9803
# 208 Train accuracy: 1.0 Test accuracy 0.9801
# 209 Train accuracy: 1.0 Test accuracy 0.9804
# 210 Train accuracy: 1.0 Test accuracy 0.9799
# 211 Train accuracy: 1.0 Test accuracy 0.9802
# 212 Train accuracy: 1.0 Test accuracy 0.9803
# 213 Train accuracy: 1.0 Test accuracy 0.9802
# 214 Train accuracy: 1.0 Test accuracy 0.9802
# 215 Train accuracy: 1.0 Test accuracy 0.9802
# 216 Train accuracy: 1.0 Test accuracy 0.9804
# 217 Train accuracy: 1.0 Test accuracy 0.9802
# 218 Train accuracy: 1.0 Test accuracy 0.9804
# 219 Train accuracy: 1.0 Test accuracy 0.9802
# 220 Train accuracy: 1.0 Test accuracy 0.98
# 221 Train accuracy: 1.0 Test accuracy 0.9802
# 222 Train accuracy: 1.0 Test accuracy 0.9801
# 223 Train accuracy: 1.0 Test accuracy 0.9803
# 224 Train accuracy: 1.0 Test accuracy 0.9798
# 225 Train accuracy: 1.0 Test accuracy 0.9801
# 226 Train accuracy: 1.0 Test accuracy 0.98
# 227 Train accuracy: 1.0 Test accuracy 0.9801
# 228 Train accuracy: 1.0 Test accuracy 0.9801
# 229 Train accuracy: 1.0 Test accuracy 0.9802
# 230 Train accuracy: 1.0 Test accuracy 0.9799
# 231 Train accuracy: 1.0 Test accuracy 0.9801
# 232 Train accuracy: 1.0 Test accuracy 0.9802
# 233 Train accuracy: 1.0 Test accuracy 0.98
# 234 Train accuracy: 1.0 Test accuracy 0.9802
# 235 Train accuracy: 1.0 Test accuracy 0.9802
# 236 Train accuracy: 1.0 Test accuracy 0.9803
# 237 Train accuracy: 1.0 Test accuracy 0.9804
# 238 Train accuracy: 1.0 Test accuracy 0.9804
# 239 Train accuracy: 1.0 Test accuracy 0.9804
# 240 Train accuracy: 1.0 Test accuracy 0.9803
# 241 Train accuracy: 1.0 Test accuracy 0.9802
# 242 Train accuracy: 1.0 Test accuracy 0.9801
# 243 Train accuracy: 1.0 Test accuracy 0.9803
# 244 Train accuracy: 1.0 Test accuracy 0.9804
# 245 Train accuracy: 1.0 Test accuracy 0.9803
# 246 Train accuracy: 1.0 Test accuracy 0.9802
# 247 Train accuracy: 1.0 Test accuracy 0.9803
# 248 Train accuracy: 1.0 Test accuracy 0.98
# 249 Train accuracy: 1.0 Test accuracy 0.9801
# 250 Train accuracy: 1.0 Test accuracy 0.98
# 251 Train accuracy: 1.0 Test accuracy 0.9804
# 252 Train accuracy: 1.0 Test accuracy 0.9803
# 253 Train accuracy: 1.0 Test accuracy 0.9801
# 254 Train accuracy: 1.0 Test accuracy 0.9804
# 255 Train accuracy: 1.0 Test accuracy 0.9803
# 256 Train accuracy: 1.0 Test accuracy 0.9803
# 257 Train accuracy: 1.0 Test accuracy 0.9804
# 258 Train accuracy: 1.0 Test accuracy 0.9803
# 259 Train accuracy: 1.0 Test accuracy 0.9802
# 260 Train accuracy: 1.0 Test accuracy 0.9802
# 261 Train accuracy: 1.0 Test accuracy 0.9805
# 262 Train accuracy: 1.0 Test accuracy 0.9799
# 263 Train accuracy: 1.0 Test accuracy 0.9803
# 264 Train accuracy: 1.0 Test accuracy 0.9803
# 265 Train accuracy: 1.0 Test accuracy 0.9802
# 266 Train accuracy: 1.0 Test accuracy 0.9805
# 267 Train accuracy: 1.0 Test accuracy 0.9801
# 268 Train accuracy: 1.0 Test accuracy 0.9803
# 269 Train accuracy: 1.0 Test accuracy 0.9803
# 270 Train accuracy: 1.0 Test accuracy 0.9801
# 271 Train accuracy: 1.0 Test accuracy 0.9804
# 272 Train accuracy: 1.0 Test accuracy 0.9802
# 273 Train accuracy: 1.0 Test accuracy 0.9802
# 274 Train accuracy: 1.0 Test accuracy 0.9803
# 275 Train accuracy: 1.0 Test accuracy 0.9801
# 276 Train accuracy: 1.0 Test accuracy 0.9801
# 277 Train accuracy: 1.0 Test accuracy 0.9801
# 278 Train accuracy: 1.0 Test accuracy 0.98
# 279 Train accuracy: 1.0 Test accuracy 0.9805
# 280 Train accuracy: 1.0 Test accuracy 0.9802
# 281 Train accuracy: 1.0 Test accuracy 0.9801
# 282 Train accuracy: 1.0 Test accuracy 0.9804
# 283 Train accuracy: 1.0 Test accuracy 0.9801
# 284 Train accuracy: 1.0 Test accuracy 0.9802
# 285 Train accuracy: 1.0 Test accuracy 0.9802
# 286 Train accuracy: 1.0 Test accuracy 0.9803
# 287 Train accuracy: 1.0 Test accuracy 0.9803
# 288 Train accuracy: 1.0 Test accuracy 0.9804
# 289 Train accuracy: 1.0 Test accuracy 0.98
# 290 Train accuracy: 1.0 Test accuracy 0.9801
# 291 Train accuracy: 1.0 Test accuracy 0.9802
# 292 Train accuracy: 1.0 Test accuracy 0.9805
# 293 Train accuracy: 1.0 Test accuracy 0.9802
# 294 Train accuracy: 1.0 Test accuracy 0.9803
# 295 Train accuracy: 1.0 Test accuracy 0.9803
# 296 Train accuracy: 1.0 Test accuracy 0.9803
# 297 Train accuracy: 1.0 Test accuracy 0.9801
# 298 Train accuracy: 1.0 Test accuracy 0.9803
# 299 Train accuracy: 1.0 Test accuracy 0.9803
# 300 Train accuracy: 1.0 Test accuracy 0.9803
# 301 Train accuracy: 1.0 Test accuracy 0.9802
# 302 Train accuracy: 1.0 Test accuracy 0.9803
# 303 Train accuracy: 1.0 Test accuracy 0.9804
# 304 Train accuracy: 1.0 Test accuracy 0.98
# 305 Train accuracy: 1.0 Test accuracy 0.9802
# 306 Train accuracy: 1.0 Test accuracy 0.98
# 307 Train accuracy: 1.0 Test accuracy 0.9802
# 308 Train accuracy: 1.0 Test accuracy 0.9803
# 309 Train accuracy: 1.0 Test accuracy 0.9801
# 310 Train accuracy: 1.0 Test accuracy 0.9803
# 311 Train accuracy: 1.0 Test accuracy 0.9801
# 312 Train accuracy: 1.0 Test accuracy 0.9804
# 313 Train accuracy: 1.0 Test accuracy 0.9803
# 314 Train accuracy: 1.0 Test accuracy 0.9802
# 315 Train accuracy: 1.0 Test accuracy 0.9804
# 316 Train accuracy: 1.0 Test accuracy 0.9801
# 317 Train accuracy: 1.0 Test accuracy 0.9803
# 318 Train accuracy: 1.0 Test accuracy 0.9802
# 319 Train accuracy: 1.0 Test accuracy 0.9801
# 320 Train accuracy: 1.0 Test accuracy 0.9801
# 321 Train accuracy: 1.0 Test accuracy 0.9801
# 322 Train accuracy: 1.0 Test accuracy 0.9802
# 323 Train accuracy: 1.0 Test accuracy 0.9804
# 324 Train accuracy: 1.0 Test accuracy 0.9801
# 325 Train accuracy: 1.0 Test accuracy 0.9802
# 326 Train accuracy: 1.0 Test accuracy 0.9803
# 327 Train accuracy: 1.0 Test accuracy 0.98
# 328 Train accuracy: 1.0 Test accuracy 0.9801
# 329 Train accuracy: 1.0 Test accuracy 0.98
# 330 Train accuracy: 1.0 Test accuracy 0.9802
# 331 Train accuracy: 1.0 Test accuracy 0.9802
# 332 Train accuracy: 1.0 Test accuracy 0.9801
# 333 Train accuracy: 1.0 Test accuracy 0.9802
# 334 Train accuracy: 1.0 Test accuracy 0.9802
# 335 Train accuracy: 1.0 Test accuracy 0.98
# 336 Train accuracy: 1.0 Test accuracy 0.9802
# 337 Train accuracy: 1.0 Test accuracy 0.9801
# 338 Train accuracy: 1.0 Test accuracy 0.98
# 339 Train accuracy: 1.0 Test accuracy 0.9801
# 340 Train accuracy: 1.0 Test accuracy 0.9803
# 341 Train accuracy: 1.0 Test accuracy 0.9803
# 342 Train accuracy: 1.0 Test accuracy 0.9802
# 343 Train accuracy: 1.0 Test accuracy 0.9801
# 344 Train accuracy: 1.0 Test accuracy 0.9801
# 345 Train accuracy: 1.0 Test accuracy 0.9801
# 346 Train accuracy: 1.0 Test accuracy 0.98
# 347 Train accuracy: 1.0 Test accuracy 0.9802
# 348 Train accuracy: 1.0 Test accuracy 0.9802
# 349 Train accuracy: 1.0 Test accuracy 0.98
# 350 Train accuracy: 1.0 Test accuracy 0.9801
# 351 Train accuracy: 1.0 Test accuracy 0.9801
# 352 Train accuracy: 1.0 Test accuracy 0.9802
# 353 Train accuracy: 1.0 Test accuracy 0.9802
# 354 Train accuracy: 1.0 Test accuracy 0.9803
# 355 Train accuracy: 1.0 Test accuracy 0.98
# 356 Train accuracy: 1.0 Test accuracy 0.9801
# 357 Train accuracy: 1.0 Test accuracy 0.9801
# 358 Train accuracy: 1.0 Test accuracy 0.98
# 359 Train accuracy: 1.0 Test accuracy 0.9802
# 360 Train accuracy: 1.0 Test accuracy 0.9801
# 361 Train accuracy: 1.0 Test accuracy 0.9801
# 362 Train accuracy: 1.0 Test accuracy 0.9803
# 363 Train accuracy: 1.0 Test accuracy 0.9801
# 364 Train accuracy: 1.0 Test accuracy 0.98
# 365 Train accuracy: 1.0 Test accuracy 0.9798
# 366 Train accuracy: 1.0 Test accuracy 0.98
# 367 Train accuracy: 1.0 Test accuracy 0.9802
# 368 Train accuracy: 1.0 Test accuracy 0.9802
# 369 Train accuracy: 1.0 Test accuracy 0.9801
# 370 Train accuracy: 1.0 Test accuracy 0.9799
# 371 Train accuracy: 1.0 Test accuracy 0.9801
# 372 Train accuracy: 1.0 Test accuracy 0.9801
# 373 Train accuracy: 1.0 Test accuracy 0.9801
# 374 Train accuracy: 1.0 Test accuracy 0.9801
# 375 Train accuracy: 1.0 Test accuracy 0.9801
# 376 Train accuracy: 1.0 Test accuracy 0.9801
# 377 Train accuracy: 1.0 Test accuracy 0.9801
# 378 Train accuracy: 1.0 Test accuracy 0.9798
# 379 Train accuracy: 1.0 Test accuracy 0.9799
# 380 Train accuracy: 1.0 Test accuracy 0.9798
# 381 Train accuracy: 1.0 Test accuracy 0.9801
# 382 Train accuracy: 1.0 Test accuracy 0.9801
# 383 Train accuracy: 1.0 Test accuracy 0.9801
# 384 Train accuracy: 1.0 Test accuracy 0.9801
# 385 Train accuracy: 1.0 Test accuracy 0.98
# 386 Train accuracy: 1.0 Test accuracy 0.98
# 387 Train accuracy: 1.0 Test accuracy 0.9802
# 388 Train accuracy: 1.0 Test accuracy 0.9801
# 389 Train accuracy: 1.0 Test accuracy 0.9802
# 390 Train accuracy: 1.0 Test accuracy 0.9801
# 391 Train accuracy: 1.0 Test accuracy 0.9802
# 392 Train accuracy: 1.0 Test accuracy 0.98
# 393 Train accuracy: 1.0 Test accuracy 0.98
# 394 Train accuracy: 1.0 Test accuracy 0.9801
# 395 Train accuracy: 1.0 Test accuracy 0.9799
# 396 Train accuracy: 1.0 Test accuracy 0.98
# 397 Train accuracy: 1.0 Test accuracy 0.9799
# 398 Train accuracy: 1.0 Test accuracy 0.9799
# 399 Train accuracy: 1.0 Test accuracy 0.98

# %%
# Regression On IAPS Images

import numpy as np
import tensorflow as tf
from scipy import misc

n_inputs = 1024*768 # Image Size
n_hidden1 = 300
n_hidden2 = 100
n_outputs = 10

X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
y = tf.placeholder(tf.int64, shape=(None), name="y")

def neuron_layer(X, n_neurons, name, activation=None):
    with tf.name_scope(name):
        n_inputs = int(X.get_shape()[1])
        stddev = 2 / np.sqrt(n_inputs)
        init = tf.truncated_normal((n_inputs, n_neurons), stddev=stddev)
        W = tf.Variable(init, name="weights")
        b = tf.Variable(tf.zeros([n_neurons]), name="biases")
        z = tf.matmul(X,W) + b
        if activation=="relu":
            return tf.nn.relu(z)
        else:
            return z

with tf.name_scope("dnn"):
    hidden1 = neuron_layer(X, n_hidden1, "hidden1", activation="relu")
    hidden2 = neuron_layer(hidden1, n_hidden2, "hidden2", activation="relu")
    logits = neuron_layer(hidden2, n_outputs, "outputs")

    
with tf.name_scope("loss"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy, name="loss")

learning_rate = 0.01

with tf.name_scope("train"):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)
    
with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))
    
init = tf.global_variables_initializer()
saver = tf.train.Saver()
